# %% [markdown]
# # A description of the data and how it will be used to solve the problem

# %% [markdown]
# - Data Sources
# Firstly, I downloaded 'red-light-camera-locations.csv' for exploring where they are located in Chicago. Secondly, 'US_Accident_DATAA.csv' was chosen for exloring which area the car accidents happend in Chicago. I got these two datasets from Kaggle. Since it should be shown on the map, longtitude and latitude are needed in both datasets.
#
# - Data Cleaning
# To get needed datas only, I processed data cleaning by SQL.
# In the case of 'red-light-camera-locations.csv', I selected 'longtitute' and 'latitude' only in the dataset.
# In the case of 'US_Accident_DATAA.CSV', I made table filtered by city's name which is 'Chicago'.

# %%
import ibm_db

# %%
dsn_hostname = "dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net" 
dsn_uid = "rnj04448"       
dsn_pwd = "n5n65dx2lq1^qt7f"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"        
dsn_port = "50000"          
dsn_protocol = "TCPIP"

# %%
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)
print(dsn)
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=BLUDB;HOSTNAME=dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=rnj04448;PWD=n5n65dx2lq1^qt7f;

# %%
try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  rnj04448 on host:  dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net

# %%
# !pip install ipython-sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://rnj04448:n5n65dx2lq1%5Eqt7f@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB

# %%
# %sql SELECT *  FROM CHICAGO_CAMERA LIMIT 5
# Out:
#  * ibm_db_sa://rnj04448:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('California-Peterson', 'NB', 'EB', None, '2009-06-29T00:00:00.000', Decimal('41.990442'), Decimal('-87.699401'), '{\'latitude\': \'41.990442\', \'human_address\': \'{"address": "", "city": "", "state": "", "zip": ""}\', \'longitude\': \'-87.699401\'}', 46, 4450, 20, 15, 24),
#  ('Central-Addison', 'SB', 'EB', None, '2010-11-15T00:00:00.000', Decimal('41.945877'), Decimal('-87.766754'), '{\'latitude\': \'41.945877\', \'human_address\': \'{"address": "", "city": "", "state": "", "zip": ""}\', \'longitude\': \'-87.766754\'}', 25, 22254, 15, 361, 44),
#  ('Western-63rd', 'NB', 'EB', None, '2007-11-12T00:00:00.000', Decimal('41.779214'), Decimal('-87.683638'), '{\'latitude\': \'41.779214\', \'human_address\': \'{"address": "", "city": "", "state": "", "zip": ""}\', \'longitude\': \'-87.683638\'}', 44, 22257, 64, 370, 2),
# ...

# %%
# %sql SELECT latitude, longitude  FROM CHICAGO_CAMERA LIMIT 5
# Out:
#  * ibm_db_sa://rnj04448:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('41.990442'), Decimal('-87.699401')),
#  (Decimal('41.945877'), Decimal('-87.766754')),
#  (Decimal('41.779214'), Decimal('-87.683638')),
#  (Decimal('41.750643'), Decimal('-87.644043')),
#  (Decimal('41.885700'), Decimal('-87.637000'))]

# %%
# %sql SELECT *  FROM US_ACCIDENT_DATAA LIMIT 5
# Out:
#  * ibm_db_sa://rnj04448:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('A-745607', 'MapQuest', 241, 2, 43825, Decimal('43825.85469'), Decimal('31.588751'), Decimal('-85.278580'), 'Lane blocked due to accident on US-431 both ways before AL-10.', None, 'US Highway 431 N', 'R', 'Abbeville', 'Henry', 'AL', '36310', 'US', 'US/Central', 'KDHN', Decimal('43825.82847'), 62, 62, 80, Decimal('29.76'), Decimal('10.00'), 'ENE', 3, Decimal('0.00'), 'Fair', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'Night', 'Night', 'Night', 'Night'),
# ...

# %%
# %sql SELECT *  FROM US_ACCIDENT_DATAA WHERE city_name = 'Chicago' LIMIT 5
# Out:
#  * ibm_db_sa://rnj04448:***@dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('A-745684', 'MapQuest', 201, 2, 43825, Decimal('43825.60616'), Decimal('42.011959'), Decimal('-87.777527'), 'Accident on Touhy Ave both ways at Meade Ave.', 5993, 'W Touhy Ave', 'L', 'Chicago', 'Cook', 'IL', '60646-1263', 'US', 'US/Central', 'KORD', Decimal('43825.57708'), 61, 61, 64, Decimal('29.19'), Decimal('10.00'), 'WSW', 13, Decimal('0.00'), 'Mostly Cloudy', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'FALSE', 'Day', 'Day', 'Day', 'Day'),
# ...
